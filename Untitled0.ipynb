# %%
import pydecode.display as display  
from parsing_hypergraph import ParsingAlgo
sentence = "A B C"
parsing = ParsingAlgo(sentence, "data/initial_values")
#This creates the hypergraph. I should rename it to create_hypergraph
parsing.get_hypergraph() 
parsing.display()
display.HypergraphFormatter(parsing.hypergraph).to_ipython()
# Out:
# [] [<pydecode.hyper.Node object at 0x337b238>] None False
# tri right 0-0 0.0337493531406
# tri right 1-1 0.0129865678027
# triStop right 1-1 0.0207627844065
# triStop left 1-1 0.0337493531406
# tri right 2-2 0.0132617522031
# triStop right 2-2 0.0204875990748
# tri left 2-2 0.0082131838426
# triStop left 2-2 0.0255361683667
# triStop right 3-3 0.0337493531406
# tri left 3-3 0.0106293596327
# triStop left 3-3 0.0231199916452
# trap right 0-1 0.0249827764928
# tri right 0-1 0.012186720036
# trap left 1-2 0.0082131838426
# trap right 1-2 0.0112084560096
# tri left 1-2 0.0082131838426
# tri right 1-2 0.00654091220349
# triStop left 1-2 0.0082131838426
# triStop right 1-2 0.0046357922256
# trap left 2-3 0.0104388482869
# trap right 2-3 0.0132617522031
# tri left 2-3 0.00806803163141
# tri right 2-3 0.0132617522031
# triStop left 2-3 0.00770515203476
# triStop right 2-3 0.0132617522031
# trap right 0-2 0.0121020479128
# tri right 0-2 0.00795312039554
# trap left 1-3 0.000553391990252
# trap right 1-3 0.00368323200382
# tri left 1-3 0.00292420806363
# tri right 1-3 0.00835077557713
# triStop left 1-3 0.00292420806363
# triStop right 1-3 0.00835077557713
# trap right 0-3 0.0168043673038
# tri right 0-3 0.0337493531406
# triStop right 0-3 0.0337493531406

# %%
import pydecode.display as display  
from parsing_hypergraph import ParsingAlgo
sentence = "A B C"
parsing = ParsingAlgo(sentence, "data/initial_values")
#This creates the hypergraph. I should rename it to create_hypergraph
parsing.get_hypergraph() 
parsing.display()
display.HypergraphFormatter(parsing.hypergraph).to_ipython()
# Out:
# [] [<pydecode.hyper.Node object at 0x332d9b8>] None False
# tri right 0-0 0.0337493531406
# tri right 1-1 0.0129865678027
# triStop right 1-1 0.0207627844065
# triStop left 1-1 0.0337493531406
# tri right 2-2 0.0132617522031
# triStop right 2-2 0.0204875990748
# tri left 2-2 0.0082131838426
# triStop left 2-2 0.0255361683667
# triStop right 3-3 0.0337493531406
# tri left 3-3 0.0106293596327
# triStop left 3-3 0.0231199916452
# trap right 0-1 0.0249827764928
# tri right 0-1 0.012186720036
# trap left 1-2 0.0082131838426
# trap right 1-2 0.0112084560096
# tri left 1-2 0.0082131838426
# tri right 1-2 0.00654091220349
# triStop left 1-2 0.0082131838426
# triStop right 1-2 0.0046357922256
# trap left 2-3 0.0104388482869
# trap right 2-3 0.0132617522031
# tri left 2-3 0.00806803163141
# tri right 2-3 0.0132617522031
# triStop left 2-3 0.00770515203476
# triStop right 2-3 0.0132617522031
# trap right 0-2 0.0121020479128
# tri right 0-2 0.00795312039554
# trap left 1-3 0.000553391990252
# trap right 1-3 0.00368323200382
# tri left 1-3 0.00292420806363
# tri right 1-3 0.00835077557713
# triStop left 1-3 0.00292420806363
# triStop right 1-3 0.00835077557713
# trap right 0-3 0.0168043673038
# tri right 0-3 0.0337493531406
# triStop right 0-3 0.0337493531406
